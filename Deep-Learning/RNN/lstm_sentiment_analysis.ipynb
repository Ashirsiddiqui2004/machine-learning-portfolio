# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

# %%
sentences = [
    "I love this movie",
    "This film was terrible",
    "Amazing experience",
    "Worst movie ever",
    "I enjoyed the ending",
    "The plot was boring"
]

labels = [1, 0, 1, 0, 1, 0]  # 1 = positive, 0 = negative

# %%
tokenizer = keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(sentences)

sequences = tokenizer.texts_to_sequences(sentences)
padded_sequences = keras.preprocessing.sequence.pad_sequences(sequences)

# %%
import numpy as np

X = np.array(padded_sequences, dtype="int32")
y = np.array(labels, dtype="float32")

# %%
dataset = tf.data.Dataset.from_tensor_slices((X, y))
dataset = dataset.batch(2)

# %%
model = Sequential([
    Embedding(input_dim=1000, output_dim=16),
    LSTM(32),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(dataset, epochs=10)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.6844
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.6813
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.6778
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6737
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6688
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6630
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.6561
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6478
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6379
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.6259
